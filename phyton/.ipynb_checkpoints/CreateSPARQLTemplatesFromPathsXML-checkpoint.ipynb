# %%
from bs4 import BeautifulSoup
import os.path as ospath
import os as os

HEADERS = "PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX cidoc: <http://erlangen-crm.org/170309/>\nPREFIX vismo: <http://visit.de/ontologies/vismo/>"

# get the current script path.
here = ospath.dirname(ospath.realpath('./'))
subdir = "templates"

# Create a subdirectory, if not existing
if(not ospath.isdir(ospath.join(here, subdir))):
    os.mkdir(ospath.join(here, subdir))

# %%
def preprocess(soup):
    # Change the "name" tags to "pathName"
    names = soup.find_all('name')
    
    for name in names:
        name.name = 'pathName'
        
    # Remove line breaks after some <datatype_property>, <x> and <y> elements
    yPaths = soup.find_all('x')
    for path in yPaths:
        if path.get_text().endswith('\n'):
            path.string.replace_with(path.get_text()[:-1])
            
    yPaths = soup.find_all('y')
    for path in yPaths:
        if path.get_text().endswith('\n'):
            path.string.replace_with(path.get_text()[:-1])
            
    datatypePaths = soup.find_all('datatype_property')
    for path in datatypePaths:
        if path.get_text().endswith('\n'):
            path.string.replace_with(path.get_text()[:-1])

# %%
def createTemplate(groupName, paths):
    query = ''
    
    query += HEADERS + "\n"
    
    select = 'SELECT ?x ?type '
    
    where = 'WHERE { ?x rdf:type ?type .'
    
    optionals = ''
    
    queryFilter = "FILTER regex(str(?x), \"^ADD_ID_HERE$\", \"\")}"
    
    groupBy = 'GROUP BY ?x ?type '
    
    # Find paths with and without sub-groups
    simplePaths = []
    subGroupPaths = []
    for path in paths:
        if(path.group_id.get_text() == groupName.lower() and path.is_group.get_text() == '0'):
            simplePaths.append(path)
        elif(path.group_id.get_text() == groupName.lower() and path.is_group.get_text() == '1'):
            subGroupPaths.append(path)
       
    # Counter for termporary variables
    counter = 0
    # Work simple paths
    for path in simplePaths:
        identifier = '?' + path.id.get_text()
        select += '(group_concat(distinct ' + identifier + ';separator=\",\") as ' + identifier + 's) '
        
        # Presumably not needed
        #groupBy += identifier + ' '
        
        counter += 1
        
        # Check for path length
        if(len(path.path_array.contents) == 3):
            # 1-step Path, Ending in a Property
            optionalPart = 'OPTIONAL {\n\t?x <' + path.datatype_property.get_text() + '> ' + identifier + '}\n'
            
            optionals += optionalPart
        elif(len(path.path_array.contents) == 7):
            if(path.datatype_property.get_text() == 'empty'):
                # 3-step Path, Ending in a Reference
                optionalPart = 'OPTIONAL {\n\t?x <' + path.path_array.y.get_text() + '> ' + identifier + ' .\n\t' + identifier + ' rdf:type <' + path.path_array.find_all('x')[1].get_text() + '> . }\n'
                
                optionals += optionalPart
            else:
                # 3-step Path, Ending in a Property
                optionalPart = 'OPTIONAL {\n\t?x <' + path.path_array.y.get_text() + '> ?y' + str(counter) + ' .\n\t?y' + str(counter) + ' rdf:type <' + path.path_array.find_all('x')[1].get_text() + '> .\n\t?y' + str(counter) + ' <' + path.datatype_property.get_text() + '> ' + identifier + ' . }\n'
                
                optionals += optionalPart
        elif(len(path.path_array.contents) == 11):  
            if(path.datatype_property.get_text() == 'empty'):
                # 5-step Path, Ending in a Reference
                optionalPart = ('OPTIONAL {\n\t?x <' + path.path_array.find_all('y')[0].get_text() + '> ' + '?y' + str(counter) + ' .\n'
                                + '\t' + '?y' + str(counter) + ' rdf:type <' + path.path_array.find_all('x')[1].get_text() + '> .\n'
                                + '\t' + '?y' + str(counter) + ' <' + path.path_array.find_all('y')[1].get_text() + '> ' + identifier + ' .\n'
                                + '\t' + identifier + ' rdf:type <' + path.path_array.find_all('x')[2].get_text() + '> . }\n')
                
                optionals += optionalPart
            else:
                # 5-step Path, Ending in a Property
                optionalPart = ('OPTIONAL {\n\t?x <' + path.path_array.find_all('y')[0].get_text() + '> ' + '?y' + str(counter) + ' .\n'
                                + '\t' + '?y' + str(counter) + ' rdf:type <' + path.path_array.find_all('x')[1].get_text() + '> .\n'
                                + '\t' + '?y' + str(counter) + ' <' + path.path_array.find_all('y')[1].get_text() + '> ?y' + str(counter + 1) + ' .\n'
                                + '\t ?y' + str(counter + 1) + ' <' + path.datatype_property.get_text() + '> '  + identifier + ' . }\n')
                
                counter += 1
                optionals += optionalPart
    for path in subGroupPaths:
        identifier = '?' + path.id.get_text()
        select += '(group_concat(distinct ' + identifier + ';separator=\",\") as ' + identifier + 's) '
        
        counter += 1
        
        optionalPart = 'OPTIONAL {\n\t?x <' + path.path_array.y.get_text() + '> ' + identifier + ' .\n\t' + identifier + ' rdf:type <' + path.path_array.find_all('x')[1].get_text() + '> . }\n'
        
        optionals += optionalPart
        
        # Create sub-templates for the sub-groups of a top-level group 
        # Find all paths that are associated with the subgroup
        subGroupId = path.id.get_text()
        
        createTemplate(subGroupId, paths)
        
        #currentGroupPaths = []
        #for subPath in paths:
        #    if(subPath.group_id.get_text() == subGroupId):
        #        currentGroupPaths.append(subPath)
        
        
        
        # Check subgroups for subgroups!
            
    query += select + "\n" + where + '\n' + optionals + "\n" + queryFilter + "\n" + groupBy
    
    # Write to file
    filename = groupName + ".txt"
    filepath = ospath.join(here, subdir, filename)

    try:
        f = open(filepath, 'w')
        #templateContent = createTemplate(group, paths)
        f.write(query)
        f.close()
    except IOError:
        print('Wrong path provided')

# %%
infile = open("paths.xml","r")
contents = infile.read()
soup = BeautifulSoup(contents,'xml')

# Preprocess the XML
preprocess(soup)

# Find all paths
paths = soup.find_all('path')

# Find all top-level groups
groups = []
for path in paths:
    if path.is_group.get_text() == '1' and path.group_id.get_text() == '0':
        groups.append(path.pathName.get_text())
        
# Write to template files
for group in groups:
    createTemplate(group, paths)

# %%
groups
# Out:
# ['Object',
#  'Person',
#  'Architecture',
#  'Place',
#  'Institution',
#  'Group',
#  'Reference',
#  'Activity']

# %%
examplePaths = soup.find_all('path')
groups = []

# %%
examplePaths2 = soup.find_all('y')
for path in examplePaths2:
    print(path)
    if path.get_text().endswith('\n'):
        print('blub')
        path.string.replace_with(path.get_text()[:-1])
        #path.replace_with(path.get_text()[:-3])
        #path.get_text() = path.get_text()[:-3]
    print(path)
# Out:
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P137_exemplifies</y>
# <y>http://erlangen-crm.org/170309/P137_exemplifies</y>
# <y>http://erlangen-crm.org/170309/P48_has_preferred_identifier</y>
# <y>http://erlangen-crm.org/170309/P48_has_preferred_identifier</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P55_has_current_location</y>
# <y>http://erlangen-crm.org/170309/P55_has_current_location</y>
# <y>http://erlangen-crm.org/170309/P55_has_current_location</y>
# <y>http://erlangen-crm.org/170309/P55_has_current_location</y>
# <y>http://erlangen-crm.org/170309/P46_is_composed_of</y>
# <y>http://erlangen-crm.org/170309/P46_is_composed_of</y>
# <y>http://erlangen-crm.org/170309/P46i_forms_part_of</y>
# <y>http://erlangen-crm.org/170309/P46i_forms_part_of</y>
# <y>http://erlangen-crm.org/170309/P16i_was_used_for</y>
# <y>http://erlangen-crm.org/170309/P16i_was_used_for</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P106_is_composed_of</y>
# <y>http://erlangen-crm.org/170309/P106_is_composed_of</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P106_is_composed_of</y>
# <y>http://erlangen-crm.org/170309/P106_is_composed_of</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P126_employed</y>
# <y>http://erlangen-crm.org/170309/P126_employed</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P32_used_general_technique</y>
# <y>http://erlangen-crm.org/170309/P32_used_general_technique</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P14_carried_out_by</y>
# <y>http://erlangen-crm.org/170309/P14_carried_out_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P14_carried_out_by</y>
# <y>http://erlangen-crm.org/170309/P14_carried_out_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P43_has_dimension</y>
# <y>http://erlangen-crm.org/170309/P43_has_dimension</y>
# <y>http://erlangen-crm.org/170309/P43_has_dimension</y>
# <y>http://erlangen-crm.org/170309/P43_has_dimension</y>
# <y>http://erlangen-crm.org/170309/P91_has_unit</y>
# <y>http://erlangen-crm.org/170309/P91_has_unit</y>
# <y>http://erlangen-crm.org/170309/P43_has_dimension</y>
# <y>http://erlangen-crm.org/170309/P43_has_dimension</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P29_custody_received_by</y>
# <y>http://erlangen-crm.org/170309/P29_custody_received_by</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P29_custody_received_by</y>
# <y>http://erlangen-crm.org/170309/P29_custody_received_by</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P28_custody_surrendered_by</y>
# <y>http://erlangen-crm.org/170309/P28_custody_surrendered_by</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P28_custody_surrendered_by</y>
# <y>http://erlangen-crm.org/170309/P28_custody_surrendered_by</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P30i_custody_transferred_through</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P62_depicts</y>
# <y>http://erlangen-crm.org/170309/P62_depicts</y>
# <y>http://erlangen-crm.org/170309/P62_depicts</y>
# <y>http://erlangen-crm.org/170309/P62_depicts</y>
# <y>http://erlangen-crm.org/170309/P62_depicts</y>
# <y>http://erlangen-crm.org/170309/P62_depicts</y>
# <y>http://erlangen-crm.org/170309/P62_depicts</y>
# <y>http://erlangen-crm.org/170309/P62_depicts</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P128_carries</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P96_by_mother</y>
# <y>http://erlangen-crm.org/170309/P96_by_mother</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P97_from_father</y>
# <y>http://erlangen-crm.org/170309/P97_from_father</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by</y>
# <y>http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by</y>
# <y>http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by</y>
# <y>http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by</y>
# <y>http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of</y>
# <y>http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of</y>
# <y>http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of</y>
# <y>http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of</y>
# <y>http://erlangen-crm.org/170309/P107_has_current_or_former_member</y>
# <y>http://erlangen-crm.org/170309/P107_has_current_or_former_member</y>
# <y>http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of</y>
# <y>http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of</y>
# <y>http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of</y>
# <y>http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by</y>
# <y>http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P152i_is_parent_of</y>
# <y>http://erlangen-crm.org/170309/P152i_is_parent_of</y>
# <y>http://erlangen-crm.org/170309/P152_has_parent</y>
# <y>http://erlangen-crm.org/170309/P152_has_parent</y>
# <y>http://erlangen-crm.org/170309/P52i_is_current_owner_of</y>
# <y>http://erlangen-crm.org/170309/P52i_is_current_owner_of</y>
# <y>http://erlangen-crm.org/170309/P62i_is_depicted_by</y>
# <y>http://erlangen-crm.org/170309/P62i_is_depicted_by</y>
# <y>http://erlangen-crm.org/170309/P11i_participated_in</y>
# <y>http://erlangen-crm.org/170309/P11i_participated_in</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P62i_is_depicted_by</y>
# <y>http://erlangen-crm.org/170309/P62i_is_depicted_by</y>
# <y>http://erlangen-crm.org/170309/P55i_currently_holds</y>
# <y>http://erlangen-crm.org/170309/P55i_currently_holds</y>
# <y>http://erlangen-crm.org/170309/P137_exemplifies</y>
# <y>http://erlangen-crm.org/170309/P137_exemplifies</y>
# <y>http://erlangen-crm.org/170309/P55_has_current_location</y>
# <y>http://erlangen-crm.org/170309/P55_has_current_location</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P89i_contains</y>
# <y>http://erlangen-crm.org/170309/P89i_contains</y>
# <y>http://erlangen-crm.org/170309/P89_falls_within</y>
# <y>http://erlangen-crm.org/170309/P89_falls_within</y>
# <y>http://erlangen-crm.org/170309/P16i_was_used_for</y>
# <y>http://erlangen-crm.org/170309/P16i_was_used_for</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P17_was_motivated_by</y>
# <y>http://erlangen-crm.org/170309/P17_was_motivated_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P14_carried_out_by</y>
# <y>http://erlangen-crm.org/170309/P14_carried_out_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P15_was_influenced_by</y>
# <y>http://erlangen-crm.org/170309/P15_was_influenced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P137_exemplifies</y>
# <y>http://erlangen-crm.org/170309/P137_exemplifies</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P17_was_motivated_by</y>
# <y>http://erlangen-crm.org/170309/P17_was_motivated_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P14_carried_out_by</y>
# <y>http://erlangen-crm.org/170309/P14_carried_out_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P15_was_influenced_by</y>
# <y>http://erlangen-crm.org/170309/P15_was_influenced_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P31i_was_modified_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P55i_currently_holds</y>
# <y>http://erlangen-crm.org/170309/P55i_currently_holds</y>
# <y>http://erlangen-crm.org/170309/P7i_witnessed</y>
# <y>http://erlangen-crm.org/170309/P7i_witnessed</y>
# <y>http://erlangen-crm.org/170309/P7i_witnessed</y>
# <y>http://erlangen-crm.org/170309/P7i_witnessed</y>
# <y>http://erlangen-crm.org/170309/P92_brought_into_existence</y>
# <y>http://erlangen-crm.org/170309/P92_brought_into_existence</y>
# <y>http://erlangen-crm.org/170309/P7i_witnessed</y>
# <y>http://erlangen-crm.org/170309/P7i_witnessed</y>
# <y>http://erlangen-crm.org/170309/P93_took_out_of_existence</y>
# <y>http://erlangen-crm.org/170309/P93_took_out_of_existence</y>
# <y>http://erlangen-crm.org/170309/P62i_is_depicted_by</y>
# <y>http://erlangen-crm.org/170309/P62i_is_depicted_by</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P52i_is_current_owner_of</y>
# <y>http://erlangen-crm.org/170309/P52i_is_current_owner_of</y>
# <y>http://erlangen-crm.org/170309/P52i_is_current_owner_of</y>
# <y>http://erlangen-crm.org/170309/P52i_is_current_owner_of</y>
# <y>http://erlangen-crm.org/170309/P55i_currently_holds</y>
# <y>http://erlangen-crm.org/170309/P55i_currently_holds</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P52i_is_current_owner_of</y>
# <y>http://erlangen-crm.org/170309/P52i_is_current_owner_of</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P2_has_type</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P108i_was_produced_by</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://visit.de/ontologies/vismo/referencedBy</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P52_has_current_owner</y>
# <y>http://erlangen-crm.org/170309/P55_has_current_location</y>
# <y>http://erlangen-crm.org/170309/P55_has_current_location</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P1_is_identified_by</y>
# <y>http://erlangen-crm.org/170309/P11_had_participant</y>
# <y>http://erlangen-crm.org/170309/P11_had_participant</y>
# <y>http://erlangen-crm.org/170309/P16_used_specific_object</y>
# <y>http://erlangen-crm.org/170309/P16_used_specific_object</y>
# <y>http://erlangen-crm.org/170309/P16_used_specific_object</y>
# <y>http://erlangen-crm.org/170309/P16_used_specific_object</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P7_took_place_at</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P160_has_temporal_projection</y>
# <y>http://erlangen-crm.org/170309/P62i_is_depicted_by</y>
# <y>http://erlangen-crm.org/170309/P62i_is_depicted_by</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/reference</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>
# <y>http://visit.de/ontologies/vismo/hasDigitalRepresentation</y>

# %%
# Find highest-level groups
for path in examplePaths:
    if path.is_group.get_text() == '1' and path.group_id.get_text() == '0':
        groups.append(path.pathName.get_text())

# %%
groups
# Out:
# ['Object',
#  'Person',
#  'Architecture',
#  'Place',
#  'Institution',
#  'Group',
#  'Reference',
#  'Activity']

# %%
test = createTemplate('Person', examplePaths)

# %%
print(test)
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX cidoc: <http://erlangen-crm.org/170309/>
# PREFIX vismo: <http://visit.de/ontologies/vismo/>
# SELECT ?x ?type (group_concat(distinct ?person_idby_actorappel;separator=",") as ?person_idby_actorappels) (group_concat(distinct ?person_hastype_profession;separator=",") as ?person_hastype_professions) (group_concat(distinct ?person_firstname;separator=",") as ?person_firstnames) (group_concat(distinct ?person_lastname;separator=",") as ?person_lastnames) (group_concat(distinct ?person_pseudonym;separator=",") as ?person_pseudonyms) (group_concat(distinct ?person_alternatename;separator=",") as ?person_alternatenames) (group_concat(distinct ?person_carries_title;separator=",") as ?person_carries_titles) (group_concat(distinct ?person_comment;separator=",") as ?person_comments) (group_concat(distinct ?person_description;separator=",") as ?person_descriptions) (group_concat(distinct ?person_keyword;separator=",") as ?person_keywords) (group_concat(distinct ?person_parentof_person;separator=",") as ?person_parentof_persons) (group_concat(distinct ?person_ischildof_person;separator=",") as ?person_ischildof_persons) (group_concat(distinct ?person_ownerof_architecture;separator=",") as ?person_ownerof_architectures) (group_concat(distinct ?person_depictedon_object;separator=",") as ?person_depictedon_objects) (group_concat(distinct ?person_participatedin_activity;separator=",") as ?person_participatedin_activitys) (group_concat(distinct ?person_has_reference;separator=",") as ?person_has_references) (group_concat(distinct ?person_helpfullinks;separator=",") as ?person_helpfullinkss) (group_concat(distinct ?person_thumbnail;separator=",") as ?person_thumbnails) (group_concat(distinct ?person_birth;separator=",") as ?person_births) (group_concat(distinct ?person_death;separator=",") as ?person_deaths) (group_concat(distinct ?person_marriage;separator=",") as ?person_marriages) (group_concat(distinct ?person_digitalrepresentation;separator=",") as ?person_digitalrepresentations)
# WHERE { ?x rdf:type ?type .
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P1_is_identified_by> ?y1 .
# 	?y1 rdf:type <http://erlangen-crm.org/170309/E82_Actor_Appellation> .
# 	?y1 <http://erlangen-crm.org/170309/P3_has_note> ?person_idby_actorappel . }
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P2_has_type> ?y2 .
# 	?y2 rdf:type <http://visit.de/ontologies/vismo/Profession> .
# 	?y2 <http://erlangen-crm.org/170309/P3_has_note> ?person_hastype_profession . }
# OPTIONAL {
# 	?x <http://xmlns.com/foaf/0.1/firstName> ?person_firstname}
# OPTIONAL {
# 	?x <http://xmlns.com/foaf/0.1/lastName> ?person_lastname}
# OPTIONAL {
# 	?x <http://xmlns.com/foaf/0.1/nick> ?person_pseudonym}
# OPTIONAL {
# 	?x <http://xmlns.com/foaf/0.1/name> ?person_alternatename}
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P128_carries> ?y7 .
# 	?y7 rdf:type <http://erlangen-crm.org/170309/E35_Title> .
# 	?y7 <http://erlangen-crm.org/170309/P3_has_note> ?person_carries_title . }
# OPTIONAL {
# 	?x <http://visit.de/ontologies/vismo/comment> ?person_comment}
# OPTIONAL {
# 	?x <http://visit.de/ontologies/vismo/description> ?person_description}
# OPTIONAL {
# 	?x <http://visit.de/ontologies/vismo/keyword> ?person_keyword}
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P152i_is_parent_of> ?person_parentof_person .
# 	?person_parentof_person rdf:type <http://visit.de/ontologies/vismo/Person> . }
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P152_has_parent> ?person_ischildof_person .
# 	?person_ischildof_person rdf:type <http://visit.de/ontologies/vismo/Person> . }
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P52i_is_current_owner_of> ?person_ownerof_architecture .
# 	?person_ownerof_architecture rdf:type <http://visit.de/ontologies/vismo/Architecture> . }
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P62i_is_depicted_by> ?person_depictedon_object .
# 	?person_depictedon_object rdf:type <http://visit.de/ontologies/vismo/Object> . }
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P11i_participated_in> ?person_participatedin_activity .
# 	?person_participatedin_activity rdf:type <http://visit.de/ontologies/vismo/Activity> . }
# OPTIONAL {
# 	?x <http://visit.de/ontologies/vismo/reference> ?person_has_reference .
# 	?person_has_reference rdf:type <http://visit.de/ontologies/vismo/Reference> . }
# OPTIONAL {
# 	?x <http://visit.de/ontologies/vismo/helpfulLinks> ?person_helpfullinks}
# OPTIONAL {
# 	?x <http://visit.de/ontologies/vismo/thumbnail> ?person_thumbnail}
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P92i_was_brought_into_existence_by> ?person_birth .
# 	?person_birth rdf:type <http://erlangen-crm.org/170309/E67_Birth> . }
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P93i_was_taken_out_of_existence_by> ?person_death .
# 	?person_death rdf:type <http://erlangen-crm.org/170309/E69_Death> . }
# OPTIONAL {
# 	?x <http://erlangen-crm.org/170309/P107i_is_current_or_former_member_of> ?person_marriage .
# 	?person_marriage rdf:type <http://visit.de/ontologies/vismo/Marriage> . }
# OPTIONAL {
# 	?x <http://visit.de/ontologies/vismo/hasDigitalRepresentation> ?person_digitalrepresentation .
# 	?person_digitalrepresentation rdf:type <http://visit.de/ontologies/vismo/DigitalRepresentation> . }
#
# FILTER regex(str(?x), "^ADD_ID_HERE$", "")}
# GROUP BY ?x ?type

# %%
print("PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX cidoc: <http://erlangen-crm.org/170309/>\nPREFIX vismo: <http://visit.de/ontologies/vismo/>")
# Out:
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX cidoc: <http://erlangen-crm.org/170309/>
# PREFIX vismo: <http://visit.de/ontologies/vismo/>

# %%
len(paths[1].path_array.contents)
# Out:
# 7
